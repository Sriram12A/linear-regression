# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv('11.csv')

# %%
df.head()
# Out:
#    area    price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000

# %%
df.columns = df.columns.str.strip().str.replace('\ufeff', '')
plt.scatter(df['area'], df['price'])
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300     ]])
# Out:
# c:\Users\Sriram\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.predict([[2600]])
# Out:
# c:\Users\Sriram\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
d=pd.read_csv('info.csv')

# %%
reg.predict(d)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['price'] = reg.predict(d)

# %%
d
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv('info.csv',index=False)

# %%
df.columns = df.columns.str.strip().str.replace('\ufeff', '')
plt.scatter(df['area'], df['price'])
plt.plot(df['area'], reg.predict(df[['area']]), color='red')

# %%
e=pd.read_csv('canada_per_capita_income.csv')

# %%
e.columns = e.columns.str.strip().str.replace('\ufeff', '')
plt.scatter(e['year'], e['per capita income (US$)'])
plt.show()

# %%
reg1=linear_model.LinearRegression()
reg1.fit(e[['year']],e['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg1.predict([[2017]])
# Out:
# c:\Users\Sriram\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38803.29886875])

# %%
e.columns = e.columns.str.strip().str.replace('\ufeff', '')
plt.scatter(e['year'], e['per capita income (US$)'])
plt.plot(e['year'], reg1.predict(e[['year']]), color='red')

# %%
e['predicted_price']=reg1.predict(e[['year']])
e
# Out:
#     year  per capita income (US$)  predicted_price
# 0   1970              3399.299037      -134.559667
# 1   1971              3768.297935       693.905409
# 2   1972              4251.175484      1522.370484
# 3   1973              4804.463248      2350.835559
# 4   1974              5576.514583      3179.300634
# 5   1975              5998.144346      4007.765709
# 6   1976              7062.131392      4836.230785
# 7   1977              7100.126170      5664.695860
# 8   1978              7247.967035      6493.160935
# 9   1979              7602.912681      7321.626010
# 10  1980              8355.968120      8150.091086
# 11  1981              9434.390652      8978.556161
# 12  1982              9619.438377      9807.021236
# 13  1983             10416.536590     10635.486311
# 14  1984             10790.328720     11463.951386
# 15  1985             11018.955850     12292.416462
# 16  1986             11482.891530     13120.881537
# ...

# %%
e.to_csv('canada_per_capita_income.csv',index=False)
